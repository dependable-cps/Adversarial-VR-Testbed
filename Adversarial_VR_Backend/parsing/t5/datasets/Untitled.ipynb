# %%
import pandas as pd

# %%
file = pd.read_csv("cybersickness_pandas.csv").sample(300)
file = file.reset_index()
X= file["natural_language"]
y = file ["parsed_utterance"]
file
# Out:
#      index  Unnamed: 0                                   natural_language  \
# 0    27816       27816  if we were to increase normal right eye origin...
# 1     9535        9535  for gaze origin from world space in zax is les...
# 2    38033       38033  for gaze origin from world space in x axis upp...
# 3    27337       27337  what are some mistakes on gaze origin from wor...
# 4    13611       13611  show me people that have the model predicts lo...
# ..     ...         ...                                                ...
# 295  16450       16450  what's the average normal right eye origin in ...
# 296  15203       15203  how would you characterize the mistakes you ma...
# 297  10648       10648  what's the positive predictive value on normal...
# 298  14132       14132  for gaze origin from local space in x axis old...
# 299  38043       38043  for normal left eye origin in y axis the same ...
#
#                                       parsed_utterance
# ...

# %%
with open("cybersickness_test_suite.txt","w") as f:
    for i in range(300):
        f.write(X[i]+"\n")
        f.write(y[i]+"\n\n")
    f.close()
